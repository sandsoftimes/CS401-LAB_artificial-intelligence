# %%
#INSTRUCTIONS
#Enter LOCATION A/B in captial letters
#Enter Status O/1 accordingly where 0 means CLEAN and 1 means DIRTY

def vacuum_world():
    # Initialize goal state with both rooms as clean
    
#     goal_state = {'A': '0', 'B': '0'}
    cost = 0

    # Get user input for vacuum location and room status
    location = input("Enter floor of building (A/B): ").upper()
    status = input(f"Enter status of room {location} (0/1): ")
    other_room = 'A' if location == 'B' else 'B'
    other_status = input(f"Enter status of room {other_room} (0/1): ")

    goal_state = {location: status, other_room: other_status}
 
    print("location condition:", goal_state)

    if status == '1':
        # Vacuum is in a dirty room
        goal_state[location] = '0'
        cost += 1
        print(f"Location {location} cleaned. Cost: {cost}")
        
        
        if other_status == '1':
            # Other room is dirty
            print(f"Moving to room {other_room}")
            cost += 1
            goal_state[other_room] = '0'
            cost += 1
            print(f"Location {other_room} cleaned. Cost: {cost}")
        else:
            print(f"Room {other_room} is already clean")
    else:
        print(f"Location {location} is already clean")
        
        if other_status == '1':
            # Other room is dirty
            print(f"Moving to room {other_room}")
            cost += 1
            goal_state[other_room] = '0'
            cost += 1
            print(f"Location {other_room} cleaned. Cost: {cost}")
        else:
            print(f"Room {other_room} is already clean")

    print("\nGoal state:", goal_state)
    print("Performance measurement:", cost)

vacuum_world()
# Out:
# Enter floor of building (A/B):
# Enter status of room  (0/1):
# Enter status of room B (0/1):
# location condition: {'': '', 'B': ''}
# Location  is already clean
# Room B is already clean
#
# Goal state: {'': '', 'B': ''}
# Performance measurement: 0

# %%
#INSTRUCTIONS
#Enter LOCATION A/B in captial letters
#Enter Status O/1 accordingly where 0 means CLEAN and 1 means DIRTY

def check_capacity(capacity):
    got=int(capacity)
    print("Right now current capacity occupied in elevator by check_capacity is: ",got)
    if(got>=10):
        return False
    else:
        return True
def move_to_floor(floor_number):
    print("Moving To Floor",floor_number)
    return floor_number
def vacuum_world():
    # Initialize goal state with both rooms as clean
    
#     goal_state = {'A': '0', 'B': '0'}
    cost = 0
    # Get user input for vacuum location and room status
    print("Elevator button is pressed")
    print("Doors are opening")
    floor_number = input("Enter floor of building (1/10): ")
    location=move_to_floor(floor_number)
    print("Location variable is: ",location)
    print("Elevator can occupy upto than 10 people")
    status = input(f"Enter status/currentpeople in elevator: ")
    print("Current people in elevator:", status)
    cBool=check_capacity(status)
    if(cBool==True):
        print("Space available in the elevator")
    if(cBool==False):
        print("Space not available in elevator, it's occupied completely")
    other_room = 'A' if location == 'B' else 'B'
    other_status = input(f"Enter status of room {other_room} (0/1): ")

    goal_state = {location: status, other_room: other_status}
 
    print("location condition:", goal_state)

    if status == '1':
        # Vacuum is in a dirty room
        goal_state[location] = '0'
        cost += 1
        print(f"Location {location} cleaned. Cost: {cost}")
        
        
        if other_status == '1':
            # Other room is dirty
            print(f"Moving to room {other_room}")
            cost += 1
            goal_state[other_room] = '0'
            cost += 1
            print(f"Location {other_room} cleaned. Cost: {cost}")
        else:
            print(f"Room {other_room} is already clean")
    else:
        print(f"Location {location} is already clean")
        
        if other_status == '1':
            # Other room is dirty
            print(f"Moving to room {other_room}")
            cost += 1
            goal_state[other_room] = '0'
            cost += 1
            print(f"Location {other_room} cleaned. Cost: {cost}")
        else:
            print(f"Room {other_room} is already clean")

    print("\nGoal state:", goal_state)
    print("Performance measurement:", cost)

vacuum_world()
# Out:
# Elevator button is pressed
# Doors are opening
# Enter floor of building (1/10):
# Moving To Floor
# Location variable is:
# Elevator can occupy upto than 9 people
# Enter status/currentpeople in elevator: 9
# Current people in elevator: 9
# Right now current capacity occupied in elevator by check_capacity is:  9
# Space available in the elevator

# %% [markdown]
# #
