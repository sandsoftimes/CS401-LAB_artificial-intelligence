# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay,confusion_matrix,classification_report

# %%
np.random.seed(0)

# %%
df=pd.DataFrame({'X1':np.random.randint(1,10,size=50),
                'X2':np.random.randint(3,10,size=50),
                'Y':np.random.choice(['Bad','Good'],size=50)})

# %%
df
# Out:
#     X1  X2     Y
# 0    6   3   Bad
# 1    1   7   Bad
# 2    4   4  Good
# 3    4   7   Bad
# 4    8   4   Bad
# 5    4   5   Bad
# 6    6   5   Bad
# 7    3   3  Good
# 8    5   4  Good
# 9    8   4   Bad
# 10   7   4   Bad
# 11   9   4  Good
# 12   9   6   Bad
# 13   2   9  Good
# 14   7   6  Good
# 15   8   9  Good
# 16   8   5  Good
# 17   9   6   Bad
# 18   2   3   Bad
# 19   6   9   Bad
# 20   9   6  Good
# 21   5   8   Bad
# 22   4   7  Good
# 23   1   4  Good
# 24   4   5  Good
# 25   6   7   Bad
# 26   1   6  Good
# 27   3   7   Bad
# 28   4   9   Bad
# 29   9   7  Good
# 30   2   7   Bad
# 31   4   6  Good
# 32   4   7  Good
# 33   4   7   Bad
# 34   8   7   Bad
# 35   1   3  Good
# 36   2   9   Bad
# 37   1   7  Good
# 38   5   6   Bad
# 39   8   5  Good
# 40   4   8   Bad
# 41   3   8  Good
# 42   8   8   Bad
# 43   3   3  Good
# 44   1   4   Bad
# 45   1   8   Bad
# 46   5   4   Bad
# 47   6   6  Good
# 48   6   3   Bad
# 49   7   8  Good

# %%
pj=np.random.randint(1,10,50)
pj=pd.DataFrame({'Value1':np.random.randint(1,10,size=50),
                'Value2':np.random.randint(1,10,size=50),
                'Value3':np.random.randint(1,10,size=50),
                'Value4':np.random.choice(['Good','Pure',],50)})
pj
# Out:
#     Value1  Value2  Value3 Value4
# 0        7       1       8   Good
# 1        9       4       2   Good
# 2        9       9       9   Pure
# 3        4       9       5   Pure
# 4        3       5       8   Good
# 5        4       5       1   Pure
# 6        7       1       5   Good
# 7        4       4       1   Pure
# 8        7       8       7   Pure
# 9        6       4       5   Good
# 10       8       3       3   Pure
# 11       1       2       5   Good
# 12       9       2       7   Good
# 13       5       3       4   Good
# 14       7       2       4   Good
# 15       6       5       8   Good
# 16       9       3       9   Pure
# 17       3       6       6   Pure
# 18       4       6       1   Good
# 19       8       6       9   Good
# 20       6       3       6   Good
# 21       4       6       5   Good
# 22       5       8       8   Pure
# 23       6       8       5   Pure
# 24       4       7       2   Good
# 25       4       2       4   Good
# 26       8       7       4   Pure
# 27       8       8       3   Good
# 28       4       3       6   Pure
# 29       3       4       3   Pure
# 30       4       2       4   Pure
# 31       8       6       6   Pure
# 32       8       3       8   Pure
# 33       6       1       3   Pure
# 34       2       2       8   Pure
# 35       3       1       2   Pure
# 36       3       7       7   Pure
# 37       9       1       6   Pure
# 38       2       5       1   Pure
# 39       6       9       1   Good
# 40       9       5       4   Good
# 41       5       4       2   Pure
# 42       1       4       7   Pure
# 43       3       9       7   Pure
# 44       6       9       8   Pure
# 45       6       8       9   Good
# 46       1       1       9   Good
# 47       9       4       8   Pure
# 48       2       9       1   Good
# 49       2       8       9   Good

# %%
cj=np.linspace(1,4,20)
cj
# Out:
# array([1.        , 1.15789474, 1.31578947, 1.47368421, 1.63157895,
#        1.78947368, 1.94736842, 2.10526316, 2.26315789, 2.42105263,
#        2.57894737, 2.73684211, 2.89473684, 3.05263158, 3.21052632,
#        3.36842105, 3.52631579, 3.68421053, 3.84210526, 4.        ])

# %%
np.random.seed(0)
k=np.random.randint(1,10,20)
k
# Out:
# array([6, 1, 4, 4, 8, 4, 6, 3, 5, 8, 7, 9, 9, 2, 7, 8, 8, 9, 2, 6])

# %%
good_data=np.random.randint(low=3,high=7,size=(25,2))*np.random.normal(loc=1,scale=0.5,size=(25,2))
good_data
# Out:
# array([[ 3.77440216,  5.81469189],
#        [ 4.22290486,  4.4581959 ],
#        [ 1.46073183,  7.43257641],
#        [ 4.93904734,  3.80562529],
#        [ 0.78919549,  7.47369044],
#        [ 6.33244383,  4.85720577],
#        [ 3.17243876,  5.86328161],
#        [ 0.79512371,  5.48752666],
#        [ 8.59954305,  4.58659422],
#        [ 6.52543097,  2.48845365],
#        [ 9.1973676 ,  3.25015654],
#        [ 6.43223734,  3.59781315],
#        [ 4.0537385 ,  6.11167427],
#        [ 3.85363315,  4.00283801],
#        [ 2.93383139,  4.91019894],
#        [ 4.96913797,  3.06318224],
#        [11.87788767,  5.40472291],
#        [ 5.82633601,  1.69251478],
#        [ 5.06882079,  9.36181397],
#        [ 2.66394183,  3.94954153],
#        [ 4.49974454,  3.64655122],
#        [ 2.02363069,  1.00251923],
#        [ 1.53873006,  5.48501798],
#        [ 1.50242647,  2.4485436 ],
#        [ 7.47439863,  7.78083826]])

# %%
val=np.random.randint(low=3,high=6,size=(2,4))
val
# Out:
# array([[4, 3, 3, 3],
#        [3, 5, 5, 3]])

# %%
good_data=np.random.randint(low=3,high=7,size=(25,2))*np.random.normal(loc=1,scale=0.5,size=(25,2))

# %%
good_data
# Out:
# array([[ 3.90685842,  0.77082531],
#        [ 5.28634022,  7.72715064],
#        [ 8.2284448 ,  4.95104441],
#        [ 4.37730424,  5.52359859],
#        [ 2.07187328,  0.02766354],
#        [ 3.13459609,  5.2871347 ],
#        [ 2.82836964,  4.59754408],
#        [ 4.4445198 ,  7.3055489 ],
#        [ 2.93137785,  3.07484762],
#        [ 1.59670432,  4.5747753 ],
#        [ 4.72085453,  6.0203703 ],
#        [ 0.11856865,  5.16725357],
#        [ 3.28929129,  3.15827036],
#        [ 9.35063365,  3.27182645],
#        [ 6.68790884,  3.54533712],
#        [ 4.16541987,  1.06341232],
#        [ 2.00834365,  1.22971348],
#        [ 6.59292791,  7.24169993],
#        [ 6.39464396,  9.70838464],
#        [ 5.42844764, 12.85300006],
#        [ 7.12820516,  7.83331113],
#        [ 1.68395502,  0.56836876],
#        [ 4.25498101,  2.92433209],
#        [ 1.10994081,  2.91830273],
#        [ 0.47180302,  4.10647435]])

# %%
bad_data=np.random.randint(low=0,high=3,size=(25,2))*np.random.normal(loc=1,scale=0.5,size=(25,2))

# %%
df=pd.DataFrame({'X1':np.concatenate([good_data[:,0],bad_data[:,0]]),
                'X2':np.concatenate([good_data[:,1],bad_data[:,1]]),
                'Y':np.concatenate([['Good']*25,['Bad']*25])})
df
# Out:
#           X1         X2     Y
# 0   3.906858   0.770825  Good
# 1   5.286340   7.727151  Good
# 2   8.228445   4.951044  Good
# 3   4.377304   5.523599  Good
# 4   2.071873   0.027664  Good
# 5   3.134596   5.287135  Good
# 6   2.828370   4.597544  Good
# 7   4.444520   7.305549  Good
# 8   2.931378   3.074848  Good
# 9   1.596704   4.574775  Good
# 10  4.720855   6.020370  Good
# 11  0.118569   5.167254  Good
# 12  3.289291   3.158270  Good
# 13  9.350634   3.271826  Good
# 14  6.687909   3.545337  Good
# 15  4.165420   1.063412  Good
# 16  2.008344   1.229713  Good
# 17  6.592928   7.241700  Good
# 18  6.394644   9.708385  Good
# 19  5.428448  12.853000  Good
# 20  7.128205   7.833311  Good
# 21  1.683955   0.568369  Good
# 22  4.254981   2.924332  Good
# 23  1.109941   2.918303  Good
# 24  0.471803   4.106474  Good
# 25  2.833880   0.000000   Bad
# 26  0.699146   0.726418   Bad
# 27  1.304825   2.758932   Bad
# 28  0.407040   1.464700   Bad
# 29  1.273476   1.130408   Bad
# 30  0.000000   0.933785   Bad
# 31  0.000000   0.777621   Bad
# 32  1.188568   1.362894   Bad
# 33  0.000000   1.848958   Bad
# 34  0.000000   2.908642   Bad
# 35  0.000000   0.819049   Bad
# 36  0.000000   0.000000   Bad
# 37  0.000000   0.000000   Bad
# 38  1.691471   2.386913   Bad
# 39  0.000000   0.000000   Bad
# 40  1.516458   1.877776   Bad
# 41  1.916319   0.000000   Bad
# 42  0.000000   0.000000   Bad
# 43  0.000000   0.000000   Bad
# 44  1.296873   0.000000   Bad
# 45  1.392577   0.435630   Bad
# 46  0.266258   0.000000   Bad
# 47  0.000000   1.751195   Bad
# 48  0.000000   2.282070   Bad
# 49  0.105682   0.000000   Bad

# %%
good_data
# Out:
# array([[ 3.90685842,  0.77082531],
#        [ 5.28634022,  7.72715064],
#        [ 8.2284448 ,  4.95104441],
#        [ 4.37730424,  5.52359859],
#        [ 2.07187328,  0.02766354],
#        [ 3.13459609,  5.2871347 ],
#        [ 2.82836964,  4.59754408],
#        [ 4.4445198 ,  7.3055489 ],
#        [ 2.93137785,  3.07484762],
#        [ 1.59670432,  4.5747753 ],
#        [ 4.72085453,  6.0203703 ],
#        [ 0.11856865,  5.16725357],
#        [ 3.28929129,  3.15827036],
#        [ 9.35063365,  3.27182645],
#        [ 6.68790884,  3.54533712],
#        [ 4.16541987,  1.06341232],
#        [ 2.00834365,  1.22971348],
#        [ 6.59292791,  7.24169993],
#        [ 6.39464396,  9.70838464],
#        [ 5.42844764, 12.85300006],
#        [ 7.12820516,  7.83331113],
#        [ 1.68395502,  0.56836876],
#        [ 4.25498101,  2.92433209],
#        [ 1.10994081,  2.91830273],
#        [ 0.47180302,  4.10647435]])

# %%
good_data[:,1]
# Out:
# array([ 0.77082531,  7.72715064,  4.95104441,  5.52359859,  0.02766354,
#         5.2871347 ,  4.59754408,  7.3055489 ,  3.07484762,  4.5747753 ,
#         6.0203703 ,  5.16725357,  3.15827036,  3.27182645,  3.54533712,
#         1.06341232,  1.22971348,  7.24169993,  9.70838464, 12.85300006,
#         7.83331113,  0.56836876,  2.92433209,  2.91830273,  4.10647435])

# %%
good_data[:,0]
# Out:
# array([3.90685842, 5.28634022, 8.2284448 , 4.37730424, 2.07187328,
#        3.13459609, 2.82836964, 4.4445198 , 2.93137785, 1.59670432,
#        4.72085453, 0.11856865, 3.28929129, 9.35063365, 6.68790884,
#        4.16541987, 2.00834365, 6.59292791, 6.39464396, 5.42844764,
#        7.12820516, 1.68395502, 4.25498101, 1.10994081, 0.47180302])

# %%
good_data[1:9,1]
# Out:
# array([7.72715064, 4.95104441, 5.52359859, 0.02766354, 5.2871347 ,
#        4.59754408, 7.3055489 , 3.07484762])

# %%
good_data[0:25,0]
# Out:
# array([3.90685842, 5.28634022, 8.2284448 , 4.37730424, 2.07187328,
#        3.13459609, 2.82836964, 4.4445198 , 2.93137785, 1.59670432,
#        4.72085453, 0.11856865, 3.28929129, 9.35063365, 6.68790884,
#        4.16541987, 2.00834365, 6.59292791, 6.39464396, 5.42844764,
#        7.12820516, 1.68395502, 4.25498101, 1.10994081, 0.47180302])

# %%
bad_data[:,0]
# Out:
# array([2.83388012, 0.6991457 , 1.3048254 , 0.40704041, 1.27347601,
#        0.        , 0.        , 1.1885681 , 0.        , 0.        ,
#        0.        , 0.        , 0.        , 1.69147117, 0.        ,
#        1.51645784, 1.91631893, 0.        , 0.        , 1.29687257,
#        1.39257725, 0.26625803, 0.        , 0.        , 0.10568193])

# %%
good_data[:,1]
# Out:
# array([ 0.77082531,  7.72715064,  4.95104441,  5.52359859,  0.02766354,
#         5.2871347 ,  4.59754408,  7.3055489 ,  3.07484762,  4.5747753 ,
#         6.0203703 ,  5.16725357,  3.15827036,  3.27182645,  3.54533712,
#         1.06341232,  1.22971348,  7.24169993,  9.70838464, 12.85300006,
#         7.83331113,  0.56836876,  2.92433209,  2.91830273,  4.10647435])

# %%
bad_data[:,1]
# Out:
# array([0.        , 0.7264181 , 2.75893216, 1.46469972, 1.13040766,
#        0.93378482, 0.7776211 , 1.3628935 , 1.84895799, 2.90864239,
#        0.81904912, 0.        , 0.        , 2.38691284, 0.        ,
#        1.87777637, 0.        , 0.        , 0.        , 0.        ,
#        0.43562975, 0.        , 1.75119506, 2.28206989, 0.        ])

# %%
df=pd.DataFrame({'X1':np.concatenate([good_data[:,0],bad_data[:,0]]),
                 'X2':np.concatenate([good_data[:,1],bad_data[:,1]]),
                 'Y':np.concatenate([['Good']*25,['Bad']*25])
})
df
# Out:
#           X1         X2     Y
# 0   3.906858   0.770825  Good
# 1   5.286340   7.727151  Good
# 2   8.228445   4.951044  Good
# 3   4.377304   5.523599  Good
# 4   2.071873   0.027664  Good
# 5   3.134596   5.287135  Good
# 6   2.828370   4.597544  Good
# 7   4.444520   7.305549  Good
# 8   2.931378   3.074848  Good
# 9   1.596704   4.574775  Good
# 10  4.720855   6.020370  Good
# 11  0.118569   5.167254  Good
# 12  3.289291   3.158270  Good
# 13  9.350634   3.271826  Good
# 14  6.687909   3.545337  Good
# 15  4.165420   1.063412  Good
# 16  2.008344   1.229713  Good
# 17  6.592928   7.241700  Good
# 18  6.394644   9.708385  Good
# 19  5.428448  12.853000  Good
# 20  7.128205   7.833311  Good
# 21  1.683955   0.568369  Good
# 22  4.254981   2.924332  Good
# 23  1.109941   2.918303  Good
# 24  0.471803   4.106474  Good
# 25  2.833880   0.000000   Bad
# 26  0.699146   0.726418   Bad
# 27  1.304825   2.758932   Bad
# 28  0.407040   1.464700   Bad
# 29  1.273476   1.130408   Bad
# 30  0.000000   0.933785   Bad
# 31  0.000000   0.777621   Bad
# 32  1.188568   1.362894   Bad
# 33  0.000000   1.848958   Bad
# 34  0.000000   2.908642   Bad
# 35  0.000000   0.819049   Bad
# 36  0.000000   0.000000   Bad
# 37  0.000000   0.000000   Bad
# 38  1.691471   2.386913   Bad
# 39  0.000000   0.000000   Bad
# 40  1.516458   1.877776   Bad
# 41  1.916319   0.000000   Bad
# 42  0.000000   0.000000   Bad
# 43  0.000000   0.000000   Bad
# 44  1.296873   0.000000   Bad
# 45  1.392577   0.435630   Bad
# 46  0.266258   0.000000   Bad
# 47  0.000000   1.751195   Bad
# 48  0.000000   2.282070   Bad
# 49  0.105682   0.000000   Bad

# %%
y=np.concatenate([good_data[:,0],bad_data[:,0]])
y[0:25,]
# Out:
# array([3.90685842, 5.28634022, 8.2284448 , 4.37730424, 2.07187328,
#        3.13459609, 2.82836964, 4.4445198 , 2.93137785, 1.59670432,
#        4.72085453, 0.11856865, 3.28929129, 9.35063365, 6.68790884,
#        4.16541987, 2.00834365, 6.59292791, 6.39464396, 5.42844764,
#        7.12820516, 1.68395502, 4.25498101, 1.10994081, 0.47180302])

# %%
np.concatenate([['Good']*25,['Bad']*25])
# Out:
# array(['Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad',
#        'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad',
#        'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad', 'Bad'],
#       dtype='<U4')

# %%
df=df.sample(frac=1).reset_index(drop=True)
df
# Out:
#           X1         X2     Y
# 0   9.350634   3.271826  Good
# 1   0.105682   0.000000   Bad
# 2   6.687909   3.545337  Good
# 3   0.000000   0.000000   Bad
# 4   4.165420   1.063412  Good
# 5   2.833880   0.000000   Bad
# 6   2.008344   1.229713  Good
# 7   0.118569   5.167254  Good
# 8   1.683955   0.568369  Good
# 9   1.916319   0.000000   Bad
# 10  1.691471   2.386913   Bad
# 11  0.000000   2.282070   Bad
# 12  1.273476   1.130408   Bad
# 13  0.000000   0.000000   Bad
# 14  1.109941   2.918303  Good
# 15  1.296873   0.000000   Bad
# 16  0.407040   1.464700   Bad
# 17  2.931378   3.074848  Good
# 18  8.228445   4.951044  Good
# 19  4.254981   2.924332  Good
# 20  0.000000   0.000000   Bad
# 21  3.134596   5.287135  Good
# 22  1.188568   1.362894   Bad
# 23  0.000000   1.751195   Bad
# 24  0.471803   4.106474  Good
# 25  4.444520   7.305549  Good
# 26  3.906858   0.770825  Good
# 27  6.592928   7.241700  Good
# 28  5.286340   7.727151  Good
# 29  0.699146   0.726418   Bad
# 30  2.071873   0.027664  Good
# 31  0.000000   0.000000   Bad
# 32  4.377304   5.523599  Good
# 33  0.000000   1.848958   Bad
# 34  0.000000   2.908642   Bad
# 35  4.720855   6.020370  Good
# 36  6.394644   9.708385  Good
# 37  3.289291   3.158270  Good
# 38  5.428448  12.853000  Good
# 39  0.000000   0.819049   Bad
# 40  0.266258   0.000000   Bad
# 41  1.596704   4.574775  Good
# 42  2.828370   4.597544  Good
# 43  7.128205   7.833311  Good
# 44  0.000000   0.777621   Bad
# 45  0.000000   0.000000   Bad
# 46  1.304825   2.758932   Bad
# 47  0.000000   0.933785   Bad
# 48  1.516458   1.877776   Bad
# 49  1.392577   0.435630   Bad

# %%
df=df.sample(frac=1).reset_index(drop=True)
df
# Out:
#           X1         X2     Y
# 0   0.407040   1.464700   Bad
# 1   0.266258   0.000000   Bad
# 2   2.931378   3.074848  Good
# 3   0.000000   1.848958   Bad
# 4   4.444520   7.305549  Good
# 5   1.188568   1.362894   Bad
# 6   0.000000   0.000000   Bad
# 7   0.000000   0.000000   Bad
# 8   1.296873   0.000000   Bad
# 9   4.165420   1.063412  Good
# 10  8.228445   4.951044  Good
# 11  7.128205   7.833311  Good
# 12  4.720855   6.020370  Good
# 13  6.394644   9.708385  Good
# 14  1.273476   1.130408   Bad
# 15  0.105682   0.000000   Bad
# 16  0.000000   1.751195   Bad
# 17  4.377304   5.523599  Good
# 18  3.289291   3.158270  Good
# 19  3.906858   0.770825  Good
# 20  6.687909   3.545337  Good
# 21  0.471803   4.106474  Good
# 22  1.691471   2.386913   Bad
# 23  2.008344   1.229713  Good
# 24  0.000000   2.908642   Bad
# 25  0.699146   0.726418   Bad
# 26  0.000000   0.819049   Bad
# 27  1.109941   2.918303  Good
# 28  0.000000   2.282070   Bad
# 29  1.683955   0.568369  Good
# 30  5.286340   7.727151  Good
# 31  1.304825   2.758932   Bad
# 32  1.516458   1.877776   Bad
# 33  2.828370   4.597544  Good
# 34  1.596704   4.574775  Good
# 35  1.916319   0.000000   Bad
# 36  2.071873   0.027664  Good
# 37  0.000000   0.933785   Bad
# 38  2.833880   0.000000   Bad
# 39  9.350634   3.271826  Good
# 40  0.000000   0.000000   Bad
# 41  4.254981   2.924332  Good
# 42  0.118569   5.167254  Good
# 43  0.000000   0.000000   Bad
# 44  5.428448  12.853000  Good
# 45  1.392577   0.435630   Bad
# 46  0.000000   0.777621   Bad
# 47  6.592928   7.241700  Good
# 48  3.134596   5.287135  Good
# 49  0.000000   0.000000   Bad

# %%
df.head()
# Out:
#          X1        X2     Y
# 0  0.407040  1.464700   Bad
# 1  0.266258  0.000000   Bad
# 2  2.931378  3.074848  Good
# 3  0.000000  1.848958   Bad
# 4  4.444520  7.305549  Good

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      50 non-null     float64
#  1   X2      50 non-null     float64
#  2   Y       50 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#               X1         X2
# count  50.000000  50.000000
# mean    2.362098   2.778304
# std     2.489873   2.905677
# min     0.000000   0.000000
# 25%     0.108904   0.607881
# 50%     1.556581   1.863367
# 75%     4.100780   4.457700
# max     9.350634  12.853000

# %%
plt.figure(figsize=[10,6])
plt.scatter(df['X1'],df['X2'],c=df['Y'].apply(lambda x:'red' if x=='Bad' else 'green'),marker='o')
plt.xlabel('X1: Acid Durability',fontsize=14)
plt.ylabel('X2: Strength',fontsize=14)
plt.show()

# %%
c=df['Y'].apply(lambda x:'red' if x=='Bad' else 'green')
c
# Out:
# 0       red
# 1       red
# 2     green
# 3       red
# 4     green
# 5       red
# 6       red
# 7       red
# 8       red
# 9     green
# 10    green
# 11    green
# 12    green
# 13    green
# 14      red
# 15      red
# 16      red
# 17    green
# 18    green
# 19    green
# 20    green
# 21    green
# 22      red
# 23    green
# 24      red
# 25      red
# 26      red
# 27    green
# 28      red
# 29    green
# 30    green
# 31      red
# 32      red
# 33    green
# 34    green
# 35      red
# 36    green
# 37      red
# 38      red
# 39    green
# 40      red
# 41    green
# 42    green
# 43      red
# 44    green
# 45      red
# 46      red
# 47    green
# 48    green
# 49      red
# Name: Y, dtype: object

# %%
x=df['X1']
x
# Out:
# 0     0.407040
# 1     0.266258
# 2     2.931378
# 3     0.000000
# 4     4.444520
# 5     1.188568
# 6     0.000000
# 7     0.000000
# 8     1.296873
# 9     4.165420
# 10    8.228445
# 11    7.128205
# 12    4.720855
# 13    6.394644
# 14    1.273476
# 15    0.105682
# 16    0.000000
# 17    4.377304
# 18    3.289291
# 19    3.906858
# 20    6.687909
# 21    0.471803
# 22    1.691471
# 23    2.008344
# 24    0.000000
# 25    0.699146
# 26    0.000000
# 27    1.109941
# 28    0.000000
# 29    1.683955
# 30    5.286340
# 31    1.304825
# 32    1.516458
# 33    2.828370
# 34    1.596704
# 35    1.916319
# 36    2.071873
# 37    0.000000
# 38    2.833880
# 39    9.350634
# 40    0.000000
# 41    4.254981
# 42    0.118569
# 43    0.000000
# 44    5.428448
# 45    1.392577
# 46    0.000000
# 47    6.592928
# 48    3.134596
# 49    0.000000
# Name: X1, dtype: float64

# %%
df['X2']
# Out:
# 0      1.464700
# 1      0.000000
# 2      3.074848
# 3      1.848958
# 4      7.305549
# 5      1.362894
# 6      0.000000
# 7      0.000000
# 8      0.000000
# 9      1.063412
# 10     4.951044
# 11     7.833311
# 12     6.020370
# 13     9.708385
# 14     1.130408
# 15     0.000000
# 16     1.751195
# 17     5.523599
# 18     3.158270
# 19     0.770825
# 20     3.545337
# 21     4.106474
# 22     2.386913
# 23     1.229713
# 24     2.908642
# 25     0.726418
# 26     0.819049
# 27     2.918303
# 28     2.282070
# 29     0.568369
# 30     7.727151
# 31     2.758932
# 32     1.877776
# 33     4.597544
# 34     4.574775
# 35     0.000000
# 36     0.027664
# 37     0.933785
# 38     0.000000
# 39     3.271826
# 40     0.000000
# 41     2.924332
# 42     5.167254
# 43     0.000000
# 44    12.853000
# 45     0.435630
# 46     0.777621
# 47     7.241700
# 48     5.287135
# 49     0.000000
# Name: X2, dtype: float64

# %%
df[['X1','X2']]
# Out:
#           X1         X2
# 0   0.407040   1.464700
# 1   0.266258   0.000000
# 2   2.931378   3.074848
# 3   0.000000   1.848958
# 4   4.444520   7.305549
# 5   1.188568   1.362894
# 6   0.000000   0.000000
# 7   0.000000   0.000000
# 8   1.296873   0.000000
# 9   4.165420   1.063412
# 10  8.228445   4.951044
# 11  7.128205   7.833311
# 12  4.720855   6.020370
# 13  6.394644   9.708385
# 14  1.273476   1.130408
# 15  0.105682   0.000000
# 16  0.000000   1.751195
# 17  4.377304   5.523599
# 18  3.289291   3.158270
# 19  3.906858   0.770825
# 20  6.687909   3.545337
# 21  0.471803   4.106474
# 22  1.691471   2.386913
# 23  2.008344   1.229713
# 24  0.000000   2.908642
# 25  0.699146   0.726418
# 26  0.000000   0.819049
# 27  1.109941   2.918303
# 28  0.000000   2.282070
# 29  1.683955   0.568369
# 30  5.286340   7.727151
# 31  1.304825   2.758932
# 32  1.516458   1.877776
# 33  2.828370   4.597544
# 34  1.596704   4.574775
# 35  1.916319   0.000000
# 36  2.071873   0.027664
# 37  0.000000   0.933785
# 38  2.833880   0.000000
# 39  9.350634   3.271826
# 40  0.000000   0.000000
# 41  4.254981   2.924332
# 42  0.118569   5.167254
# 43  0.000000   0.000000
# 44  5.428448  12.853000
# 45  1.392577   0.435630
# 46  0.000000   0.777621
# 47  6.592928   7.241700
# 48  3.134596   5.287135
# 49  0.000000   0.000000

# %%
X=df[['X1','X2']]
X
# Out:
#           X1         X2
# 0   0.407040   1.464700
# 1   0.266258   0.000000
# 2   2.931378   3.074848
# 3   0.000000   1.848958
# 4   4.444520   7.305549
# 5   1.188568   1.362894
# 6   0.000000   0.000000
# 7   0.000000   0.000000
# 8   1.296873   0.000000
# 9   4.165420   1.063412
# 10  8.228445   4.951044
# 11  7.128205   7.833311
# 12  4.720855   6.020370
# 13  6.394644   9.708385
# 14  1.273476   1.130408
# 15  0.105682   0.000000
# 16  0.000000   1.751195
# 17  4.377304   5.523599
# 18  3.289291   3.158270
# 19  3.906858   0.770825
# 20  6.687909   3.545337
# 21  0.471803   4.106474
# 22  1.691471   2.386913
# 23  2.008344   1.229713
# 24  0.000000   2.908642
# 25  0.699146   0.726418
# 26  0.000000   0.819049
# 27  1.109941   2.918303
# 28  0.000000   2.282070
# 29  1.683955   0.568369
# 30  5.286340   7.727151
# 31  1.304825   2.758932
# 32  1.516458   1.877776
# 33  2.828370   4.597544
# 34  1.596704   4.574775
# 35  1.916319   0.000000
# 36  2.071873   0.027664
# 37  0.000000   0.933785
# 38  2.833880   0.000000
# 39  9.350634   3.271826
# 40  0.000000   0.000000
# 41  4.254981   2.924332
# 42  0.118569   5.167254
# 43  0.000000   0.000000
# 44  5.428448  12.853000
# 45  1.392577   0.435630
# 46  0.000000   0.777621
# 47  6.592928   7.241700
# 48  3.134596   5.287135
# 49  0.000000   0.000000

# %%
X=df[['X1','X2']]
y=df['Y']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)
X_test
# Out:
#           X1        X2
# 28  0.000000  2.282070
# 11  7.128205  7.833311
# 10  8.228445  4.951044
# 41  4.254981  2.924332
# 2   2.931378  3.074848
# 27  1.109941  2.918303
# 38  2.833880  0.000000
# 31  1.304825  2.758932
# 22  1.691471  2.386913
# 4   4.444520  7.305549

# %%
X
# Out:
#           X1         X2
# 0   0.407040   1.464700
# 1   0.266258   0.000000
# 2   2.931378   3.074848
# 3   0.000000   1.848958
# 4   4.444520   7.305549
# 5   1.188568   1.362894
# 6   0.000000   0.000000
# 7   0.000000   0.000000
# 8   1.296873   0.000000
# 9   4.165420   1.063412
# 10  8.228445   4.951044
# 11  7.128205   7.833311
# 12  4.720855   6.020370
# 13  6.394644   9.708385
# 14  1.273476   1.130408
# 15  0.105682   0.000000
# 16  0.000000   1.751195
# 17  4.377304   5.523599
# 18  3.289291   3.158270
# 19  3.906858   0.770825
# 20  6.687909   3.545337
# 21  0.471803   4.106474
# 22  1.691471   2.386913
# 23  2.008344   1.229713
# 24  0.000000   2.908642
# 25  0.699146   0.726418
# 26  0.000000   0.819049
# 27  1.109941   2.918303
# 28  0.000000   2.282070
# 29  1.683955   0.568369
# 30  5.286340   7.727151
# 31  1.304825   2.758932
# 32  1.516458   1.877776
# 33  2.828370   4.597544
# 34  1.596704   4.574775
# 35  1.916319   0.000000
# 36  2.071873   0.027664
# 37  0.000000   0.933785
# 38  2.833880   0.000000
# 39  9.350634   3.271826
# 40  0.000000   0.000000
# 41  4.254981   2.924332
# 42  0.118569   5.167254
# 43  0.000000   0.000000
# 44  5.428448  12.853000
# 45  1.392577   0.435630
# 46  0.000000   0.777621
# 47  6.592928   7.241700
# 48  3.134596   5.287135
# 49  0.000000   0.000000

# %%
p=X
j=y
# Out:
# 0      Bad
# 1      Bad
# 2     Good
# 3      Bad
# 4     Good
# 5      Bad
# 6      Bad
# 7      Bad
# 8      Bad
# 9     Good
# 10    Good
# 11    Good
# 12    Good
# 13    Good
# 14     Bad
# 15     Bad
# 16     Bad
# 17    Good
# 18    Good
# 19    Good
# 20    Good
# 21    Good
# 22     Bad
# 23    Good
# 24     Bad
# 25     Bad
# 26     Bad
# 27    Good
# 28     Bad
# 29    Good
# 30    Good
# 31     Bad
# 32     Bad
# 33    Good
# 34    Good
# 35     Bad
# 36    Good
# 37     Bad
# 38     Bad
# 39    Good
# 40     Bad
# 41    Good
# 42    Good
# 43     Bad
# 44    Good
# 45     Bad
# 46     Bad
# 47    Good
# 48    Good
# 49     Bad
# Name: Y, dtype: object

# %%
p_train,p_test=train_test_split(p,test_size=0.2,random_state=0)
p_test
# Out:
#           X1        X2
# 28  0.000000  2.282070
# 11  7.128205  7.833311
# 10  8.228445  4.951044
# 41  4.254981  2.924332
# 2   2.931378  3.074848
# 27  1.109941  2.918303
# 38  2.833880  0.000000
# 31  1.304825  2.758932
# 22  1.691471  2.386913
# 4   4.444520  7.305549

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 33 to 44
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      40 non-null     float64
#  1   X2      40 non-null     float64
# dtypes: float64(2)
# memory usage: 960.0 bytes
# None

# %%
print(X_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10 entries, 28 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      10 non-null     float64
#  1   X2      10 non-null     float64
# dtypes: float64(2)
# memory usage: 240.0 bytes
# None

# %%
print(y_train.describe())
# Out:
# count      40
# unique      2
# top       Bad
# freq       21
# Name: Y, dtype: object

# %%
print(y_test.describe())
# Out:
# count       10
# unique       2
# top       Good
# freq         6
# Name: Y, dtype: object

# %%
y_test
# Out:
# 28     Bad
# 11    Good
# 10    Good
# 41    Good
# 2     Good
# 27    Good
# 38     Bad
# 31     Bad
# 22     Bad
# 4     Good
# Name: Y, dtype: object

# %%
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(X_test)
y_pred
# Out:
# array(['Bad', 'Good', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Bad', 'Bad',
#        'Good'], dtype=object)

# %%
y_test
# Out:
# 28     Bad
# 11    Good
# 10    Good
# 41    Good
# 2     Good
# 27    Good
# 38     Bad
# 31     Bad
# 22     Bad
# 4     Good
# Name: Y, dtype: object

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.8

# %%
new_data=pd.DataFrame({'X1':[6,1,3],'X2':[5,2,3]})

# %%
new_data.describe()
# Out:
#              X1        X2
# count  3.000000  3.000000
# mean   3.333333  3.333333
# std    2.516611  1.527525
# min    1.000000  2.000000
# 25%    2.000000  2.500000
# 50%    3.000000  3.000000
# 75%    4.500000  4.000000
# max    6.000000  5.000000

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      3 non-null      int64
#  1   X2      3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
new_label=knn.predict(new_data)

# %%
new_label
# Out:
# array(['Good', 'Bad', 'Good'], dtype=object)

# %%
print("Predicted Label For New Data:",new_label)
# Out:
# Predicted Label For New Data: ['Good' 'Bad' 'Good']

# %%
wdata=p
wlabel=knn.predict(wdata)
print("Predicted Label Is: ",wlabel)
# Out:
# Predicted Label Is:  ['Bad' 'Bad' 'Good' 'Bad' 'Good' 'Bad' 'Bad' 'Bad' 'Bad' 'Good' 'Good'
#  'Good' 'Good' 'Good' 'Bad' 'Bad' 'Bad' 'Good' 'Good' 'Good' 'Good' 'Good'
#  'Bad' 'Bad' 'Bad' 'Bad' 'Bad' 'Bad' 'Bad' 'Bad' 'Good' 'Bad' 'Bad' 'Good'
#  'Good' 'Bad' 'Bad' 'Bad' 'Good' 'Good' 'Bad' 'Good' 'Good' 'Bad' 'Good'
#  'Bad' 'Bad' 'Good' 'Good' 'Bad']

# %%
wlabel
wlabel[3]
# Out:
# 'Bad'

# %%
y_test
# Out:
# 28     Bad
# 11    Good
# 10    Good
# 41    Good
# 2     Good
# 27    Good
# 38     Bad
# 31     Bad
# 22     Bad
# 4     Good
# Name: Y, dtype: object

# %%
wlabel[:10]
# Out:
# array(['Bad', 'Bad', 'Good', 'Bad', 'Good', 'Bad', 'Bad', 'Bad', 'Bad',
#        'Good'], dtype=object)

# %%
waccuracy=accuracy_score(y_test,wdata)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-508-89b87d095898> in <module>
# ----> 1 waccuracy=accuracy_score(y_test,wdata)
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     190
#     191             try:
# --> 192                 return func(*args, **kwargs)
#     193             except InvalidParameterError as e:
#     194                 # When the function is just a wrapper around an estimator, we allow
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     219
#     220     # Compute accuracy for each possible representation
# --> 221     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222     check_consistent_length(y_true, y_pred, sample_weight)
#     223     if y_type.startswith("multilabel"):
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      84     y_pred : array or indicator matrix
#      85     """
# ---> 86     check_consistent_length(y_true, y_pred)
#      87     type_true = type_of_target(y_true, input_name="y_true")
#      88     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [10, 50]

# %%
p_train,p_test,y_train,y_test=train_test_split(p,y,test_size=0.2,random_state=0)

# %%
p_test
# Out:
#           X1        X2
# 28  0.000000  2.282070
# 11  7.128205  7.833311
# 10  8.228445  4.951044
# 41  4.254981  2.924332
# 2   2.931378  3.074848
# 27  1.109941  2.918303
# 38  2.833880  0.000000
# 31  1.304825  2.758932
# 22  1.691471  2.386913
# 4   4.444520  7.305549

# %%
y_train
# Out:
# 33    Good
# 35     Bad
# 26     Bad
# 34    Good
# 18    Good
# 7      Bad
# 14     Bad
# 45     Bad
# 48    Good
# 29    Good
# 15     Bad
# 30    Good
# 32     Bad
# 16     Bad
# 42    Good
# 20    Good
# 43     Bad
# 8      Bad
# 13    Good
# 25     Bad
# 5      Bad
# 17    Good
# 40     Bad
# 49     Bad
# 1      Bad
# 12    Good
# 37     Bad
# 24     Bad
# 6      Bad
# 23    Good
# 36    Good
# 21    Good
# 19    Good
# 9     Good
# 39    Good
# 46     Bad
# 3      Bad
# 0      Bad
# 47    Good
# 44    Good
# Name: Y, dtype: object

# %%
y_test
# Out:
# 28     Bad
# 11    Good
# 10    Good
# 41    Good
# 2     Good
# 27    Good
# 38     Bad
# 31     Bad
# 22     Bad
# 4     Good
# Name: Y, dtype: object

# %%
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(p_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(p_test)
y_pred
# Out:
# array(['Bad', 'Good', 'Good', 'Good', 'Good', 'Bad', 'Good', 'Bad', 'Bad',
#        'Good'], dtype=object)

# %%
accuracy=accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8
